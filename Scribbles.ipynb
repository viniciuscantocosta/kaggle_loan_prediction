# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
X_0=np.random.multivariate_normal([2,3],[[1,0],[0,1]],100)
X_1=np.random.multivariate_normal([4,1],[[2,1],[1,2]],100)
X=np.concatenate([X_0,X_1])
y=np.concatenate([np.zeros(100), np.ones(100)])

plt.scatter(X_0[:,0],X_1[:,1], label='Class 0')
plt.scatter(X_1[:,0],X_1[:,1], label='Class 1')

plt.legend()
plt.show()

# %%
X_train, X_test, Y_train

# %%
Z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 Z
#
# NameError: name 'Z' is not defined

# %%
Z[:,1]
# Out:
# array([-1.08782029, -0.85115176,  0.91345923, -0.48945734,  0.72756537,
#        -1.08842685, -1.20430242, -0.25578381,  1.51985055, -0.75289863])

# %%
plt.scatter(Z[:,0],Z[:,1])
